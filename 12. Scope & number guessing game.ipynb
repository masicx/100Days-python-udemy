# %% [markdown]
# # Day 12
# ## Namespaces: local vs global scope

# %%
# enemies = 1

# def increase_enemies():
#     enemies = 2
#     print(f"enemies inside function: {enemies}")

# increase_enemies()
# print(f"enemies outside function: {enemies}")

#local scope
# def drink_potion():
#     potion_strength = 2
#     print(potion_strength)

# drink_potion()
# print(potion_strength)

# global scope
player_health = 10

def drink_potion():
    potion_strength = 2
    print(player_health)

drink_potion()

# %%
# modifying global scope
enemies = 1

def increase_enemies():
    global enemies
    enemies = 2
    print(f"enemies inside function: {enemies}")

increase_enemies()
print(f"enemies outside function: {enemies}")

# %% [markdown]
# ## Python constants and global scope

# %%
PI = 3.14159
GOOGLE_URL = "https://www.google.com"

def my_function():
    print(PI)

my_function()
# Out:
# 3.14159

# %% [markdown]
# ## Final Project

# %%
import random
from IPython.display import clear_output
from art import GUESSING_GAME

while input("Do you want to play a game of Number Guessing? Type 'y' or 'n': ") == 'y':
    clear_output()
    print(GUESSING_GAME)
    print("Welcome to the Number Guessing Game!")
    print("I'm thinking of a number between 1 and 100.")

    number = random.randint(1, 100)
    difficulty = input("Choose a difficulty. Type 'easy' or 'hard': ")
    attempts = 0
    is_game_over = False
    
    if difficulty == 'easy':
        attempts = 10
    else:
        attempts = 5

    print(f"You have {attempts} attempts remaining to guess the number.")

    while not is_game_over:
        guess = int(input("Make a guess: "))
        if guess > number:
            print("Too high.")
            attempts -= 1
        elif guess < number:
            print("Too low.")
            attempts -= 1
        else:
            print(f"You got it! The answer was {number}.")
            is_game_over = True
        if attempts == 0:
            print("You've run out of guesses, you lose.")
            is_game_over = True
# Out:
# ___________.__                                                 .__
# \__    ___/|  |__   ____      ____  __ __   ____   ______ _____|__| ____    ____      _________    _____   ____
#   |    |   |  |  \_/ __ \    / ___\|  |  \_/ __ \ /  ___//  ___/  |/    \  / ___\    / ___\__  \  /     \_/ __ \
#   |    |   |   Y  \  ___/   / /_/  >  |  /\  ___/ \___ \ \___ \|  |   |  \/ /_/  >  / /_/  > __ \|  Y Y  \  ___/
#   |____|   |___|  /\___  >  \___  /|____/  \___  >____  >____  >__|___|  /\___  /   \___  (____  /__|_|  /\___  >
#                 \/     \/  /_____/             \/     \/     \/        \//_____/   /_____/     \/      \/     \/
#
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# You have 5 attempts remaining to guess the number.
# Too low.
# Too high.
# Too high.
# Too high.
# Too high.
# You've run out of guesses, you lose.
