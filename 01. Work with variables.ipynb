# %% [markdown]
# # Day 1

# %% [markdown]
# ## Print text

# %%
# print("Hello, World!")
print("Hello, World!\nHello, World!")
# Out:
# Hello, World!
# Hello, World!

# %% [markdown]
# ## Input a string

# %%
print("Hello, " + input("What is your name?\n") + "!")
# Out:
# Hello, !

# %% [markdown]
# ## Variables

# %%
name = input("What is your name?\n")
# print("Hello, " + name + "!")
name_length = len(name)
print(name_length)
# Out:
# 0

# %% [markdown]
# ## Variable naming

# %% [markdown]
# 1. Make sure your variable names are descriptive
# 1. Don't have spaces between words
# 1. Don't start with numbers
# 1. Don't use special words like print or input

# %% [markdown]
# ## Day one project

# %%
print("Welcome to the band name generator.")
city = input("Which city did you grow up in?\n")
pet = input("What is the name of a pet?\n")
print("Your band name could be " + city + " " + pet + "!")
# Out:
# Welcome to the band name generator.
# Your band name could be Manzanillo Mia!
