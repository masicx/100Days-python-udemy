# %% [markdown]
# # Day 10
# ## Functions with outputs

# %%
def my_function():
    return 3 * 2

print(my_function())
# Out:
# 6

# %%
def format_name(f_name, l_name):
    """Take a first and last name and format it to return the title case version of the name

    Args:
        f_name (str): The first name to format.
        l_name (str): The last name to format.

    Returns:
        str: The formatted name in title case.
    """
    if f_name == "" or l_name == "":
        return "You didn't provide valid inputs."
    formatted_f_name = f_name.title()
    formatted_l_name = l_name.title()
    return f"{formatted_f_name} {formatted_l_name}"

print(format_name("angela", "merkel"))
# Out:
# Angela Merkel

# %% [markdown]
# ## Final project

# %%
def add(n1, n2):
    return n1 + n2
def subtract(n1, n2):
    return n1 - n2
def multiply(n1, n2):
    return n1 * n2
def divide(n1, n2):
    return n1 / n2

operations = {
    "+": add,
    "-": subtract,
    "*": multiply,
    "/": divide
}
continue_calculation = "n"
result = 0
while True:
    if continue_calculation == "n":
        num1 = float(input("What's the first number? "))
    else:
        num1 = result
    operation_symbol = input("Pick an operation: +, -, *, /: ")
    num2 = float(input("What's the second number? "))

    result = operations[operation_symbol](num1, num2)
    print(f"{num1} {operation_symbol} {num2} = {result}")

    continue_calculation = input("Type 'y' to continue calculating with the current result, or type 'n' to start a new calculation.")
# Out:
# 10.0 + 10.0 = 20.0
# 20.0 - 10.0 = 10.0
# 15.0 + 2.0 = 17.0
# 17.0 / 2.0 = 8.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      19     if continue_calculation == "n":
#      20         num1 = float(input("What's the first number? "))
#      21     else:
#      22         num1 = result
# ---> 23     operation_symbol = input("Pick an operation: +, -, *, /: ")
#      24     num2 = float(input("What's the second number? "))
#      25
#      26     result = operations[operation_symbol](num1, num2)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
# ...
